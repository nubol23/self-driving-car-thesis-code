# %%
import pandas as pd

# %%
df = pd.read_csv('/home/nubol23/Documents/DriveDatasetStable/Train/train_dataset.csv')
# df = pd.read_csv('/home/nubol23/Documents/DriveDatasetStable/Val/val_dataset.csv')
print(df.shape)
df.head()
# Out:
# (400000, 5)
#    throttle  brake     steer  junction filenames
# 0       0.0    0.0  0.000000     False   0/0.png
# 1       0.7    0.0 -0.501075     False   0/1.png
# 2       0.7    0.0 -0.144204     False   0/2.png
# 3       0.7    0.0 -0.145396     False   0/3.png
# 4       0.7    0.0 -0.146945     False   0/4.png

# %%
df['folder'] = [f.split('/')[0] for f in df['filenames'].tolist()]
df['file'] = [f.split('/')[1].split('.')[0] for f in df['filenames'].tolist()]

df = df.drop(['filenames'], axis=1)

df.head()
# Out:
#    throttle  brake     steer  junction folder file
# 0       0.0    0.0  0.000000     False      0    0
# 1       0.7    0.0  0.197177     False      0    1
# 2       0.7    0.0  0.061281     False      0    2
# 3       0.7    0.0  0.061321     False      0    3
# 4       0.7    0.0  0.061349     False      0    4

# %%
df.shape
# Out:
# (80000, 6)

# %%
df_junc = df.query('junction == True')

print(df_junc.shape)
df_junc.head()
# Out:
# (5628, 6)
#      throttle  brake     steer  junction folder file
# 984  0.700000    0.0  0.000565      True      0  984
# 985  0.700000    0.0  0.000585      True      0  985
# 986  0.700000    0.0  0.000604      True      0  986
# 987  0.641389    0.0  0.000661      True      0  987
# 988  0.671079    0.0  0.000620      True      0  988

# %%
idxs = df_junc.index.tolist()
print(len(idxs))
# Out:
# 35466

# %% [markdown]
# ## Buscamos junctions
#
# Si tienen mucha separación son junctions distintos

# %%
diffs = [0]*(len(idxs)-1)
junc_idxs = []

temp_idxs = []
for i in range(len(idxs)-1):
#     diffs[i] = idxs[i+1] - idxs[i]
    diff = idxs[i+1] - idxs[i]
    
    temp_idxs.append(idxs[i])
    if diff != 1 and (idxs[i+1] != 7999 and idxs[i] != 0):
        junc_idxs.append(temp_idxs)
        temp_idxs = []
    
print(junc_idxs)
# Out:
# [[984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1052], [2871, 2872, 2873, 2874, 2875, 2876, 2877, 2878, 2879, 2880, 2881, 2882, 2883, 2884, 2885, 2886, 2887, 2888, 2889, 2890, 2891, 2892, 2893, 2894, 2895, 2896, 2897, 2898, 2899, 2900, 2901, 2902, 2903, 2904, 2905, 2906, 2907, 2908, 2909, 2910, 2911, 2912, 2913, 2914, 2915, 2916, 2917, 2918, 2919, 2920, 2921, 2922, 2923, 2924, 2925, 2926, 2927, 2928, 2929, 2930, 2931, 2932, 2933, 2934, 2935, 2936, 2937, 2938, 2939, 2940, 2941, 2942, 2943, 2944, 2945, 2946, 2947, 2948, 2949, 2950, 2951, 2952, 2953, 2954, 2955, 2956, 2957, 2958, 2959, 2960, 2961, 2962, 2963, 2964, 2965, 2966, 2967, 2968, 2969, 2970, 2971, 2972, 2973, 2974, 2975, 2976, 2977, 2978, 2979, 2980, 2981, 2982, 2983, 2984, 2985, 2986, 2987, 2988, 2989, 2990, 2991, 2992, 2993, 2994, 2995, 2996, 2997, 2998, 2999, 3000, 3001, 3002, 3003, 3004, 3005, 3006, 3007, 3008, 3009, 3010, 3011, 3012, 3013, 3014, 3015, 3016, 3017, 3018, 3019, 3020, 3021, 3022, 3023, 3024, 3025, 3026], [4272, 4273, 4274, 4275, 4276, 4277, 4278, 4279, 4280, 4281, 4282, 4283, 4284, 4285, 4286, 4287, 4288, 4289, 4290, 4291, 4292, 4293, 4294, 4295, 4296, 4297, 4298, 4299, 4300, 4301, 4302, 4303, 4304, 4305, 4306, 4307, 4308, 4309, 4310, 4311, 4312, 4313, 4314, 4315, 4316, 4317, 4318, 4319, 4320, 4321, 4322, 4323, 4324, 4325, 4326, 4327, 4328, 4329, 4330, 4331, 4332, 4333, 4334, 4335, 4336, 4337, 4338, 4339, 4340, 4341, 4342, 4343, 4344, 4345, 4346, 4347, 4348, 4349], [5298, 5299, 5300, 5301, 5302, 5303, 5304, 5305, 5306, 5307, 5308, 5309, 5310, 5311, 5312, 5313, 5314, 5315, 5316, 5317, 5318, 5319, 5320, 5321, 5322, 5323, 5324, 5325, 5326, 5327, 5328, 5329, 5330, 5331, 5332, 5333, 5334, 5335, 5336, 5337, 5338, 5339, 5340, 5341, 5342, 5343, 5344, 5345, 5346, 5347, 5348, 5349, 5350, 5351, 5352, 5353, 5354, 5355, 5356, 5357, 5358, 5359, 5360, 5361, 5362, 5363, 5364, 5365, 5366], [6858, 6859, 6860, 6861, 6862, 6863, 6864, 6865, 6866, 6867, 6868, 6869, 6870, 6871, 6872, 6873, 6874, 6875, 6876, 6877, 6878, 6879, 6880, 6881, 6882, 6883, 6884, 6885, 6886, 6887, 6888, 6889, 6890, 6891, 6892, 6893, 6894, 6895, 6896, 6897, 6898, 6899], [9421, 9422, 9423, 9424, 9425, 9426, 9427, 9428, 9429, 9430, 9431, 9432, 9433, 9434, 9435, 9436, 9437, 9438, 9439, 9440, 9441, 9442, 9443, 9444, 9445, 9446, 9447, 9448, 9449, 9450, 9451, 9452, 9453, 9454, 9455, 9456, 9457, 9458, 9459, 9460, 9461, 9462, 9463, 9464, 9465, 9466, 9467, 9468, 9469, 9470, 9471, 9472, 9473, 9474, 9475, 9476, 9477, 9478, 9479, 9480, 9481, 9482, 9483, 9484, 9485, 9486, 9487, 9488, 9489, 9490, 9491, 9492, 9493, 9494, 9495, 9496, 9497, 9498, 9499, 9500, 9501, 9502, 9503, 9504, 9505, 9506, 9507, 9508, 9509, 9510, 9511, 9512, 9513, 9514, 9515, 9516, 9517, 9518, 9519, 9520, 9521, 9522, 9523, 9524, 9525, 9526, 9527, 9528, 9529, 9530, 9531, 9532, 9533, 9534, 9535, 9536, 9537, 9538, 9539, 9540, 9541, 9542, 9543, 9544, 9545, 9546, 9547, 9548, 9549, 9550, 9551, 9552, 9553, 9554, 9555, 9556, 9557, 9558, 9559, 9560, 9561, 9562, 9563, 9564, 9565, 9566, 9567, 9568, 9569], [11954, 11955, 11956, 11957, 11958, 11959, 11960, 11961, 11962, 11963, 11964, 11965, 11966, 11967, 11968, 11969, 11970, 11971, 11972, 11973, 11974, 11975, 11976, 11977, 11978, 11979, 11980, 11981, 11982, 11983, 11984, 11985, 11986, 11987, 11988, 11989, 11990, 11991, 11992, 11993, 11994, 11995, 11996, 11997, 11998, 11999, 12000, 12001, 12002, 12003, 12004, 12005, 12006, 12007, 12008, 12009, 12010, 12011, 12012, 12013, 12014, 12015, 12016, 12017, 12018], [12317, 12318, 12319, 12320, 12321, 12322, 12323, 12324, 12325, 12326, 12327, 12328, 12329, 12330, 12331, 12332, 12333, 12334, 12335, 12336, 12337, 12338, 12339, 12340, ...

# %%
import os
from shutil import copy
from tqdm import tqdm

# %%
base_path = '/home/nubol23/Documents/DriveDatasetStable/Val/junctions'
origin_path = '/home/nubol23/Documents/DriveDatasetStable/Val/Images'

for i, junc_img_idxs in tqdm(enumerate(junc_idxs)):
    os.makedirs(f'{base_path}/{i}')
    for idx in junc_img_idxs:
        row = df.iloc[idx]
        folder, file = row['filenames'].split('/')
        
        copy(f'{origin_path}/{folder}/rgb/{file}', f'{base_path}/{i}/{folder}_{file}')
# Out:
# 82it [00:14,  5.59it/s]
